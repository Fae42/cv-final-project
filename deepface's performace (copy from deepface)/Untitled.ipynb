# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %%
img_path1="img2.jpg"
img_path2='img3.jpg'

# %%
img=cv2.imread(img_path2)
plt.imshow(img[:,:,::-1])

# %%
img=cv2.imread(img_path1)
plt.imshow(img[:,:,::-1])

# %%
obj=DeepFace.verify(img1_path=img_path1,img2_path=img_path2)
obj
# Out:
# {'verified': False,
#  'distance': 0.6966089548739571,
#  'threshold': 0.4,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 516, 'y': 192, 'w': 512, 'h': 512},
#   'img2': {'x': 363, 'y': 349, 'w': 835, 'h': 835}},
#  'time': 8.15}

# %%
first_key = next(iter(obj))  # 获取字典的第一个键
first_value = obj[first_key]  # 获取第一个键对应的值
first_value
# Out:
# False

# %%
path="D:\jupyter_projs\deepface-master\tests\dataset"
DeepFace.find(img_path1,".")
# Out:
# WARNING: Representations for images in . folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  67  representations found in  representations_vgg_face.pkl
# find function lasts  1.1328392028808594  seconds
# [                   identity  source_x  source_y  source_w  source_h  \
#  0    tests/dataset/img2.jpg       516       192       512       512
#  1    tests/dataset/img4.jpg       516       192       512       512
#  2    tests/dataset/img6.jpg       516       192       512       512
#  3    tests/dataset/img7.jpg       516       192       512       512
#  4    tests/dataset/img5.jpg       516       192       512       512
#  5   tests/dataset/img11.jpg       516       192       512       512
#  6   tests/dataset/img10.jpg       516       192       512       512
# ...

# %%
obj = DeepFace.analyze(img_path = "couple.jpg", actions = ['age', 'gender', 'race', 'emotion'])
# Out:
# ...
# Action: emotion: 100%|███████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.64it/s]

# %%
obj
# Out:
# [{'age': 31,
#   'region': {'x': 1437, 'y': 339, 'w': 675, 'h': 675},
#   'gender': {'Woman': 0.006757658411515877, 'Man': 99.99324083328247},
#   'dominant_gender': 'Man',
#   'race': {'asian': 1.8276045414930036,
#    'indian': 1.4567980416772415,
#    'black': 0.2942500055432326,
#    'white': 41.75473651346404,
#    'middle eastern': 10.618680491290151,
#    'latino hispanic': 44.04793608760072},
#   'dominant_race': 'latino hispanic',
#   'emotion': {'angry': 6.843778491020203,
#    'disgust': 0.3268019063398242,
#    'fear': 61.303508281707764,
#    'happy': 0.008804448589216918,
#    'sad': 28.724128007888794,
#    'surprise': 1.0035395622253418,
#    'neutral': 1.789437048137188},
#   'dominant_emotion': 'fear'},
#  {'age': 31,
#   'region': {'x': 318, 'y': 534, 'w': 779, 'h': 779},
#   'gender': {'Woman': 99.95701909065247, 'Man': 0.04297861305531114},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 3.66428904235363,
#    'indian': 1.4354325830936432,
# ...
